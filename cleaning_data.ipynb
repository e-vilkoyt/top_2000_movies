# %% [markdown]
# # Loading data

# %%
import pandas as pd

df = pd.read_csv('top_movies.csv') # read csv file

# %% [markdown]
# First review to the DataFrame

# %%
df.shape
# Out:
# (2000, 10)

# %%
df.dtypes
# Out:
# Movie Name       object
# Release Year     object
# Duration          int64
# IMDB Rating     float64
# Metascore       float64
# Votes            object
# Genre            object
# Director         object
# Cast             object
# Gross            object
# dtype: object

# %% [markdown]
# Standarize the column's names.

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %% [markdown]
# Clean the values of the release year.

# %%
df['release_year'].unique()
# Out:
# array(['1972', '1974', '1980', '1962', '1971', '1977', '1968', '1967',
#        '1960', '1940', '1946', '1957', '1965', '1966', '1953', '1948',
#        '1963', '1958', '1964', '1975', '1954', '1979', '1976', '1961',
#        '1941', '1949', '1950', '1956', '1973', '1981', '1970',
#        '1964–1968', '1939', '1955', '1945', '1978', '1959', '1944',
#        '1969', '1951', '1982', '1931', '1952', '1926', '1925', '1934',
#        '1936', '1927', '1921', '1932', '1933', '1937', '1988', '1986',
#        '1983', '1987', '1985', '1991', '1984', '1989', '1990', 'I 1987',
#        '1992', 'I 1990', '1996', '1995', '1993', '1994', '1997', 'I 1995',
#        'I 1996', '1995–2016', 'I 1999', '2001', '1998 Video', '1999',
#        '2000', '1998', 'I 1998', 'I 2000', '1998 TV Movie',
#        '1999 TV Movie', '2001 TV Movie', '2004', '2003', '2002', 'I 2003',
#        'I 2002', 'I 2004', '2005', '2006', '2005 Video', 'I 2005',
#        'II 2004', '2006 TV Movie', 'I 2006', '2007', '2008', 'I 2007',
#        'I 2008', 'II 2005', '2007 Video', '2007 TV Movie', '2006 Video',
#        '2008 TV Movie', '2009', '2010', 'I 2009', '2010 TV Movie',
#        '2009 Video', 'I 2010', 'II 2009'], dtype=object)

# %%
import re

def extract_year(value):
    match = re.search(r'\b(19|20)\d{2}\b', value)
    return match.group(0) if match else None

# Aplicar la función a la columna 'year'
df['clean_year'] =df['release_year'].apply(extract_year)

# Convertir la columna 'clean_year' a números enteros, manejar errores
df['clean_year'] = pd.to_numeric(df['clean_year'], errors='coerce')

# %% [markdown]
# Clean the gender's column.

# %%
# Separar los géneros en la columna 'genre' por comas
df['genres'] = df['genre'].str.split(',')
# Explode la columna de géneros para tener una fila por cada género
df_exploded = df.explode('genres')
#Quitamos los espacios y las minúsculas
df_exploded['genres'] = df_exploded['genres'].str.strip().str.lower()
df.head(10)
# Out:
#                            movie_name release_year  duration  imdb_rating  \
# 0                       The Godfather         1972       175          9.2
# 1               The Godfather Part II         1974       202          9.0
# 2                     Ordinary People         1980       124          7.7
# 3                  Lawrence of Arabia         1962       218          8.3
# 4                          Straw Dogs         1971       113          7.4
# 5  Close Encounters of the Third Kind         1977       138          7.6
# 6        Once Upon a Time in the West         1968       166          8.5
# 7                     The Dirty Dozen         1967       150          7.7
# 8                     Rosemary's Baby         1968       137          8.0
# 9                             Cabaret         1972       124          7.8
#
#    metascore      votes                        genre              director  \
# 0      100.0  2,002,655                 Crime, Drama  Francis Ford Coppola
# 1       90.0  1,358,608                 Crime, Drama  Francis Ford Coppola
# 2       86.0     56,476                        Drama        Robert Redford
# 3      100.0    313,044  Adventure, Biography, Drama            David Lean
# 4       73.0     64,331       Crime, Drama, Thriller         Sam Peckinpah
# 5       90.0    216,050                Drama, Sci-Fi      Steven Spielberg
# 6       82.0    348,110                      Western          Sergio Leone
# 7       73.0     78,858       Action, Adventure, War        Robert Aldrich
# 8       96.0    234,034                Drama, Horror        Roman Polanski
# 9       80.0     59,119        Drama, Music, Musical             Bob Fosse
#
#                 cast     gross  clean_year                           genres
# 0      Marlon Brando  $134.97M        1972                  [Crime,  Drama]
# 1          Al Pacino   $57.30M        1974                  [Crime,  Drama]
# 2  Donald Sutherland   $54.80M        1980                          [Drama]
# 3      Peter O'Toole   $44.82M        1962  [Adventure,  Biography,  Drama]
# 4     Dustin Hoffman       NaN        1971       [Crime,  Drama,  Thriller]
# 5   Richard Dreyfuss  $132.09M        1977                 [Drama,  Sci-Fi]
# 6        Henry Fonda    $5.32M        1968                        [Western]
# 7         Lee Marvin   $45.30M        1967       [Action,  Adventure,  War]
# 8         Mia Farrow       NaN        1968                 [Drama,  Horror]
# 9      Liza Minnelli   $42.77M        1972        [Drama,  Music,  Musical]

# %%
df_exploded['genres'].unique()
# Out:
# array(['crime', 'drama', 'adventure', 'biography', 'thriller', 'sci-fi',
#        'western', 'action', 'war', 'horror', 'music', 'musical',
#        'mystery', 'romance', 'film-noir', 'comedy', 'family', 'fantasy',
#        'sport', 'animation', 'history', 'documentary'], dtype=object)

# %%
df = df.drop(columns = ['release_year', 'genre', 'duration', 'votes'])

# %%
df.rename(columns={'clean_year': 'release_year'}, inplace=True)

# %%
df.sample(10)
# Out:
#                                movie_name  imdb_rating  metascore  \
# 293                           Beetlejuice          7.5       71.0
# 1592                   Meet the Robinsons          6.8       61.0
# 1773                            Eden Lake          6.7       65.0
# 1822  Transformers: Revenge of the Fallen          6.0       35.0
# 377           Once Upon a Time in America          8.3       75.0
# 1904           Ghosts of Girlfriends Past          5.8       34.0
# 1584                          The Holiday          6.9       52.0
# 121                            Goldfinger          7.7       87.0
# 669                          Philadelphia          7.7       66.0
# 979                           Coyote Ugly          5.7       27.0
#
#                  director                 cast     gross  release_year  \
# 293            Tim Burton         Alec Baldwin   $73.71M          1988
# 1592  Stephen J. Anderson        Daniel Hansen   $97.82M          2007
# 1773        James Watkins         Kelly Reilly    $0.01M          2008
# 1822          Michael Bay         Shia LaBeouf  $402.11M          2009
# 377          Sergio Leone       Robert De Niro    $5.32M          1984
# 1904          Mark Waters  Matthew McConaughey   $55.25M          2009
# 1584         Nancy Meyers         Kate Winslet   $63.22M          2006
# 121          Guy Hamilton         Sean Connery   $51.08M          1964
# 669        Jonathan Demme            Tom Hanks   $77.32M          1993
# 979         David McNally         Piper Perabo   $60.79M          2000
#
#                                 genres
# 293                 [Comedy,  Fantasy]
# 1592  [Animation,  Adventure,  Comedy]
# 1773               [Horror,  Thriller]
# 1822     [Action,  Adventure,  Sci-Fi]
# 377                    [Crime,  Drama]
# 1904      [Comedy,  Fantasy,  Romance]
# 1584                [Comedy,  Romance]
# 121    [Action,  Adventure,  Thriller]
# 669                            [Drama]
# 979           [Comedy,  Drama,  Music]

# %%
df.to_csv('top_movies_cleaned.csv', index=False)

# %%
df2 = pd.read_csv('top_movies_cast.csv') # read csv file

# %%
df2.head(10)
# Out:
#    Unnamed: 0                                         Moive Name  Rating  \
# 0           0                             Leave the World Behind     6.5
# 1           1                                              Wonka     7.4
# 2           2                                        Poor Things     8.5
# 3           3                         Killers of the Flower Moon     7.8
# 4           4                                       May December     7.0
# 5           5   The Hunger Games: The Ballad of Songbirds & S...     7.1
# 6           6                                           Napoleon     6.6
# 7           7                                        Oppenheimer     8.4
# 8           8                                      Love Actually     7.6
# 9           9                                    Candy Cane Lane     5.6
#
#       Votes  Meta Score                         Genre PG Rating  Year  \
# 0   90000.0        67.0      Drama, Mystery, Thriller         R  2023
# 1   24000.0        66.0     Adventure, Comedy, Family        PG  2023
# 2    6700.0        86.0        Comedy, Drama, Romance         R  2023
# 3  128000.0        89.0         Crime, Drama, History         R  2023
# 4   21000.0        85.0                 Comedy, Drama         R  2023
# 5   56000.0        54.0      Action, Adventure, Drama     PG-13  2023
# 6   66000.0        64.0  Action, Adventure, Biography         R  2023
# 7  553000.0        89.0     Biography, Drama, History         R  2023
# 8  517000.0        55.0        Comedy, Drama, Romance         R  2003
# 9   13000.0        47.0       Comedy, Family, Fantasy        PG  2023
#
#   Duration                                               Cast  \
# 0   2h 18m  Julia Roberts, Mahershala Ali, Ethan Hawke, My...
# 1   1h 56m  Timothée Chalamet, Gustave Die, Murray McArthu...
# 2   2h 21m  Emma Stone, Mark Ruffalo, Willem Dafoe, Ramy Y...
# 3   3h 26m  Leonardo DiCaprio, Robert De Niro, Lily Gladst...
# 4   1h 57m  Natalie Portman, Chris Tenzis, Charles Melton,...
# 5   2h 37m  Rachel Zegler, Tom Blyth, Viola Davis, Dexter ...
# 6   2h 38m  Joaquin Phoenix, Vanessa Kirby, Tahar Rahim, R...
# 7       3h  Cillian Murphy, Emily Blunt, Matt Damon, Rober...
# 8   2h 15m  Hugh Grant, Martine McCutcheon, Liam Neeson, L...
# 9   1h 57m  Eddie Murphy, Tracee Ellis Ross, Jillian Bell,...
#
#             Director
# 0         Sam Esmail
# 1          Paul King
# 2   Yorgos Lanthimos
# 3    Martin Scorsese
# 4        Todd Haynes
# 5   Francis Lawrence
# 6       Ridley Scott
# 7  Christopher Nolan
# 8     Richard Curtis
# 9    Reginald Hudlin

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Moive Name', 'Rating', 'Votes', 'Meta Score', 'Genre',
#        'PG Rating', 'Year', 'Duration', 'Cast', 'Director'],
#       dtype='object')
