# %% [markdown]
# # Loading data

# %%
import pandas as pd

df = pd.read_csv('top_movies.csv') # read csv file

# %% [markdown]
# First review to the DataFrame

# %%
df.shape
# Out:
# (1950, 11)

# %% [markdown]
# Standarize the column's names.

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')
df = df.rename(columns={'moive_name': 'title'})

# %%
df = df.dropna(subset=['cast', 'director'])

# %%
df.sample(5)
# Out:
#      unnamed:_0                    title  rating      votes  meta_score  \
# 562         562   The Outlaw Josey Wales     7.8    79000.0        69.0
# 511         511       American History X     8.5  1200000.0        62.0
# 316         316            Casino Royale     8.0   685000.0        80.0
# 965         965           School of Rock     7.2   324000.0        82.0
# 971         971                Malignant     6.2   105000.0        51.0
#
#                            genre pg_rating  year duration  \
# 562                      Western        PG  1976   2h 15m
# 511                 Crime, Drama         R  1998   1h 59m
# 316  Action, Adventure, Thriller     PG-13  2006   2h 24m
# 965                Comedy, Music     PG-13  2003   1h 49m
# 971       Crime, Horror, Mystery         R  2021   1h 51m
#
#                                                   cast           director
# 562  Clint Eastwood, Sondra Locke, Chief Dan George...     Clint Eastwood
# 511  Edward Norton, Edward Furlong, Beverly D'Angel...          Tony Kaye
# 316  Daniel Craig, Eva Green, Judi Dench, Jeffrey W...    Martin Campbell
# 965   Jack Black, Mike White, Joan Cusack, Adam Pascal  Richard Linklater
# 971  Annabelle Wallis, Maddie Hasson, George Young,...          James Wan

# %%
df = df.drop(columns = ['unnamed:_0', 'votes', 'pg_rating', 'duration'])

# %%
df.sample(10)
# Out:
#                                title  rating  meta_score  \
# 601     Zack Snyder's Justice League     7.9        54.0
# 143    Once Upon a Time in Hollywood     7.6        83.0
# 1079                        Sinister     6.8        53.0
# 1258                           Borat     7.4        89.0
# 509                    The Lost City     6.1        60.0
# 612                   13 Going on 30     6.3        57.0
# 957                   Legally Blonde     6.4        59.0
# 1276     Sicario: Day of the Soldado     7.1        61.0
# 678                    Beautiful Boy     7.4        62.0
# 405                  Boyz n the Hood     7.8        76.0
#
#                            genre  year  \
# 601   Action, Adventure, Fantasy  2021
# 143                Comedy, Drama  2019
# 1079   Horror, Mystery, Thriller  2012
# 1258                      Comedy  2006
# 509    Action, Adventure, Comedy  2022
# 612     Comedy, Fantasy, Romance  2004
# 957              Comedy, Romance  2001
# 1276        Action, Crime, Drama  2018
# 678             Biography, Drama  2018
# 405                 Crime, Drama  1991
#
#                                                    cast              director
# 601     Henry Cavill, Ben Affleck, Gal Gadot, Amy Adams           Zack Snyder
# 143   Leonardo DiCaprio, Brad Pitt, Margot Robbie, E...     Quentin Tarantino
# 1079  Ethan Hawke, Juliet Rylance, James Ransone, Fr...      Scott Derrickson
# 1258  Sacha Baron Cohen, Ken Davitian, Luenell, Chester         Larry Charles
# 509   Sandra Bullock, Channing Tatum, Daniel Radclif...     Aaron NeeAdam Nee
# 612   Jennifer Garner, Mark Ruffalo, Judy Greer, And...           Gary Winick
# 957   Reese Witherspoon, Luke Wilson, Selma Blair, M...        Robert Luketic
# 1276  Benicio Del Toro, Josh Brolin, Isabela Merced,...       Stefano Sollima
# 678   Steve Carell, Maura Tierney, Jack Dylan Grazer...  Felix van Groeningen
# 405   Cuba Gooding Jr., Laurence Fishburne, Hudhail ...        John Singleton

# %%
# Convertir las columnas 'genre' y 'cast' en listas
df['genre'] = df['genre'].apply(lambda x: x.split(', '))
df['cast'] = df['cast'].apply(lambda x: x.split(', '))
# Out:
#                          title  rating  meta_score  \
# 0       Leave the World Behind     6.5        67.0
# 1                        Wonka     7.4        66.0
# 2                  Poor Things     8.5        86.0
# 3   Killers of the Flower Moon     7.8        89.0
# 4                 May December     7.0        85.0
#
#                          genre  year  \
# 0   [Drama, Mystery, Thriller]  2023
# 1  [Adventure, Comedy, Family]  2023
# 2     [Comedy, Drama, Romance]  2023
# 3      [Crime, Drama, History]  2023
# 4              [Comedy, Drama]  2023
#
#                                                 cast          director
# 0  [Julia Roberts, Mahershala Ali, Ethan Hawke, M...        Sam Esmail
# 1  [Timothée Chalamet, Gustave Die, Murray McArth...         Paul King
# 2  [Emma Stone, Mark Ruffalo, Willem Dafoe, Ramy ...  Yorgos Lanthimos
# 3  [Leonardo DiCaprio, Robert De Niro, Lily Glads...   Martin Scorsese
# 4  [Natalie Portman, Chris Tenzis, Charles Melton...       Todd Haynes

# %%
df.dtypes
# Out:
# title          object
# rating        float64
# meta_score    float64
# genre          object
# year            int64
# cast           object
# director       object
# dtype: object

# %% [markdown]
# ## DataFrame con los beneficios que han dado las películas

# %%
revenue_df = pd.read_csv('revenue_movies_dataset.csv') # read csv file

# %%
def clean_title(title):
    # Convertir a minúsculas
    title = title.lower()
    # Eliminar espacios en blanco al principio y al final
    title = title.strip()
    # Reemplazar caracteres especiales (opcional, depende de tus datos)
    title = title.replace("'", "")  # Eliminar apóstrofes
    title = title.replace(":", "")  # Eliminar dos puntos
    return title

# Aplicar la función de limpieza en ambas columnas 'title'
df['title'] = df['title'].apply(clean_title)
revenue_df['title'] = revenue_df['title'].apply(clean_title)

# %%
# Unir df original con el revenue_df
df_merged = pd.merge(df, revenue_df, on='title', how='inner')

# Ver los primeros resultados del DataFrame unido
df_merged.sample(10)
# Out:
#                                    title  rating  meta_score  \
# 182                    godzilla vs. kong     6.3        59.0
# 1820                          mr. nobody     7.7        63.0
# 43                                  wish     5.8        47.0
# 1228                            i, tonya     7.5        77.0
# 635                           inside out     8.1        94.0
# 674                    to catch a killer     6.6        43.0
# 512   indiana jones and the last crusade     8.2        65.0
# 1891                         john carter     6.6        51.0
# 1958             anna and the apocalypse     6.1        63.0
# 1195           the man who knew too much     7.4        76.0
#
#                                genre  year  \
# 182       [Action, Sci-Fi, Thriller]  2021
# 1820       [Drama, Fantasy, Romance]  2009
# 43    [Animation, Adventure, Comedy]  2023
# 1228      [Biography, Comedy, Drama]  2017
# 635   [Animation, Adventure, Comedy]  2015
# 674           [Action, Crime, Drama]  2023
# 512              [Action, Adventure]  1989
# 1891     [Action, Adventure, Sci-Fi]  2012
# 1958       [Comedy, Horror, Musical]  2017
# 1195               [Drama, Thriller]  1956
#
#                                                    cast  \
# 182   [Alexander Skarsgård, Millie Bobby Brown, Rebe...
# 1820  [Jared Leto, Sarah Polley, Diane Kruger, Linh-...
# 43    [Ariana DeBose, Chris Pine, Alan Tudyk, Angeli...
# 1228  [Margot Robbie, Sebastian Stan, Allison Janney...
# 635   [Amy Poehler, Bill Hader, Lewis Black, Mindy K...
# 674   [Shailene Woodley, Ben Mendelsohn, Jovan Adepo...
# 512   [Harrison Ford, Sean Connery, Alison Doody, De...
# 1891  [Taylor Kitsch, Lynn Collins, Willem Dafoe, Sa...
# 1958  [Ella Hunt, Malcolm Cumming, Sarah Swire, Chri...
# 1195  [James Stewart, Doris Day, Brenda de Banzie, B...
#
#                           director    revenue
# 182                   Adam Wingard  470116094
# 1820              Jaco Van Dormael    2331721
# 43    Chris BuckFawn Veerasunthorn          0
# 1228               Craig Gillespie   53939297
# 635   Pete DocterRonnie Del Carmen          0
# 674                 Damián Szifron     200221
# 512               Steven Spielberg  474171806
# 1891                Andrew Stanton  284139100
# 1958                  John McPhail          0
# 1195              Alfred Hitchcock   11300000

# %%
df_merged.to_csv('top_movies_cleaned.csv', index=False)
